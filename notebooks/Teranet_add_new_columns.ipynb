# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os

# %%
# Set some parameters to apply to all plots. These can be overridden
# in each plot if desired
import matplotlib
# Plot size to 14" x 7"
# matplotlib.rc('figure', figsize = (14, 7))
# Font size to 14
matplotlib.rc('font', size = 14)
# Do not display top and right frame lines
matplotlib.rc('axes.spines', top = False, right = False)
# Remove grid lines
matplotlib.rc('axes', grid = False)
# Set background color to white
matplotlib.rc('axes', facecolor = 'white')

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'data',
#  'img',
#  'notebooks',
#  'presentations',
#  'README.md',
#  'src',
#  '__pycache__']

# %% [markdown]
# # Create xy-level table from Teranet data
#
# This notebook describes the creation process for a DataFrame (table) with xy-level data derived from Teranet records.
#
# Proposed schema of the xy-level table:
#
# <img src='img/xy_table_scheme.HEIC'></img>
# <img src='img/xy_table_scheme.png'></img>

# %% [markdown]
# ## Load cleaned Teranet dataset with `da_in` column
# `da_id` column was produced via a spatial join between Teranet points and DA polygons
# (for details, see notebook `Teranet_GTHA_DA_spatial_join.ipynb`)

# %%
# column `pin` will be converted to dtype=category
# after records with NaN `consideration_amt` will be dropped
dtypes = {
    'decade': 'int',
    'year': 'int',
    'lro_num': 'category',
    'postal_code': 'category',
    'street_designation': 'category',
    'street_direction': 'category',
    'municipality': 'category',
    'da_id': 'category',
    'da_city': 'category',
}
drop_cols = ['Unnamed: 0', 'index', 
             'index_right', 'province',
             'street_suffix']
t = time.time()
teranet_path = 'data/HHSaleHistory_cleaned_v0.9_GTHA_DA.csv'
df = pd.read_csv(teranet_path, 
                 parse_dates=['registration_date'],
                 dtype=dtypes)
df = df.drop(drop_cols, axis=1)
df = df.sort_values(['pin',
                     'registration_date'])
elapsed = time.time() - t
print("----- DataFrame with Teranet records loaded"
      "\nin {0:.2f} seconds".format(elapsed) + 
      "\nwith {0:,} rows\nand {1:,} columns"
      .format(df.shape[0], df.shape[1]) + 
      "\n-- Column names:\n", df.columns)
# Out:
# ----- DataFrame with Teranet records loaded
# in 41.71 seconds
# with 6,062,853 rows
# and 18 columns
# -- Column names:
#  Index(['registration_date', 'decade', 'year', 'lro_num', 'pin',
#        'consideration_amt', 'postal_code', 'unitno', 'street_name',
#        'street_designation', 'street_direction', 'municipality',
#        'street_number', 'x', 'y', 'da_id', 'da_city', 'da_median_tot_inc'],
#       dtype='object')

# %%
df.head()
# Out:
#         registration_date  decade  year lro_num       pin  consideration_amt  \
# 5242184        1986-07-09     198  1986      65  29000001           185000.0
# 5242178        1986-04-14     198  1986      65  29000002           171000.0
# 5242214        1988-09-09     198  1988      65  29000003           318000.0
# 5242377        1999-01-29     199  1999      65  29000003           273000.0
# 5242545        2011-02-18     201  2011      65  29000003           558000.0
#
#         postal_code  unitno street_name street_designation street_direction  \
# 5242184      L3P6K5     NaN      Cairns                 Dr              NaN
# 5242178      L3P6K5     NaN      Cairns                 Dr              NaN
# 5242214      L3P6K5     NaN      Cairns                 Dr              NaN
# 5242377      L3P6K5     NaN      Cairns                 Dr              NaN
# 5242545      L3P6K5     NaN      Cairns                 Dr              NaN
#
#         municipality  street_number          x          y da_id  da_city  \
# 5242184      Markham          120.0 -79.280389  43.887265  1608  Markham
# 5242178      Markham          118.0 -79.280309  43.887118  1608  Markham
# 5242214      Markham          116.0 -79.280255  43.887000  1608  Markham
# 5242377      Markham          116.0 -79.280255  43.887000  1608  Markham
# 5242545      Markham          116.0 -79.280255  43.887000  1608  Markham
#
#          da_median_tot_inc
# 5242184            28032.0
# 5242178            28032.0
# 5242214            28032.0
# 5242377            28032.0
# 5242545            28032.0

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6062853 entries, 5242184 to 6062631
# Data columns (total 18 columns):
# registration_date     6062853 non-null datetime64[ns]
# decade                6062853 non-null int32
# year                  6062853 non-null int32
# lro_num               6062853 non-null category
# pin                   6062853 non-null int64
# consideration_amt     4637584 non-null float64
# postal_code           5534039 non-null category
# unitno                1339242 non-null float64
# street_name           5874264 non-null object
# street_designation    5516855 non-null category
# street_direction      520896 non-null category
# municipality          6058942 non-null category
# street_number         5870282 non-null float64
# x                     6062853 non-null float64
# y                     6062853 non-null float64
# da_id                 6062853 non-null category
# da_city               6062853 non-null category
# da_median_tot_inc     6021553 non-null float64
# dtypes: category(7), datetime64[ns](1), float64(6), int32(2), int64(1), object(1)
# memory usage: 584.5+ MB

# %% [markdown]
# ### Drop all records with missing (or <$30) `consideration_amt`

# %%
df = df.dropna(subset=['consideration_amt'])
df['pin'] = df['pin'].astype('category')
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4637584 entries, 5242184 to 6062631
# Data columns (total 18 columns):
# registration_date     4637584 non-null datetime64[ns]
# decade                4637584 non-null int32
# year                  4637584 non-null int32
# lro_num               4637584 non-null category
# pin                   4637584 non-null category
# consideration_amt     4637584 non-null float64
# postal_code           4342478 non-null category
# unitno                1140626 non-null float64
# street_name           4588439 non-null object
# street_designation    4327098 non-null category
# street_direction      424608 non-null category
# municipality          4635981 non-null category
# street_number         4587129 non-null float64
# x                     4637584 non-null float64
# y                     4637584 non-null float64
# da_id                 4637584 non-null category
# da_city               4637584 non-null category
# da_median_tot_inc     4608506 non-null float64
# dtypes: category(8), datetime64[ns](1), float64(6), int32(2), object(1)
# memory usage: 527.8+ MB

# %% [markdown]
# ### Unique records by `pin`
# Column `pin` can be used for grouping operations with Teranet data.

# %%
df['pin'].describe()
# Out:
# count       4637584
# unique      2219927
# top       211080033
# freq            464
# Name: pin, dtype: int64

# %% [markdown]
# ### Unique records by `xy`
# Column `xy` is produced by concatenating `x` and `y` coordinates as strings. It can be used for grouping operations with Teranet data.

# %%
df['xy'] = df['x'].astype('str') + df['y'].astype('str')
df['xy'].describe()
# Out:
# count                                 4637584
# unique                                1394189
# top       -79.413759934962343.776162782863395
# freq                                     7222
# Name: xy, dtype: object

# %% [markdown]
# There is a significant discrepancy between the number of records with unique `pin` and the number of records with unique `xy` (# with same `xy` > # with same `pin`).

# %%
pin_counts = df['pin'].value_counts()
xy_counts = df['xy'].value_counts()

f, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
plt.title("Histogram of records")

pin_counts.hist(bins=100, ax=axes[0])
axes[0].set_title("\nfor all pins ({0:,} pins total)"
                  .format(len(pin_counts)))
axes[0].set_ylabel("# of pins")
axes[0].set_xlabel("# of records")
axes[0].grid(linestyle=':')

xy_counts.hist(bins=100, ax=axes[1])
axes[1].set_title("\nfor all xy pairs ({0:,} pairs total)"
                  .format(len(xy_counts)))
axes[1].set_ylabel("# of xy pairs")
axes[1].set_xlabel("# of records")
axes[1].grid(linestyle=':')

plt.show()

# %%
max_counts = 10

f, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
plt.title("Histogram of records")

pin_counts[pin_counts < max_counts].hist(bins=20, 
                                         ax=axes[0])
axes[0].set_title("for pins with <{0} records"
                  .format(max_counts) + 
                  "\n({0:,} pins ({1:.5f}% of the total)"
          .format(len(pin_counts[pin_counts < max_counts]),
                  len(pin_counts[pin_counts < max_counts])
                            / len(pin_counts) * 100))
axes[0].set_ylabel("# of pins")
axes[0].set_xlabel("# of records")
axes[0].grid(linestyle=':')

xy_counts[xy_counts < max_counts].hist(bins=20, 
                                       ax=axes[1])
axes[1].set_title("\nfor xy pairs with <{0} records"
                  .format(max_counts) + 
            "\n({0:,} pairs ({1:.5f}% of the total)"
                  .format(len(xy_counts[xy_counts < max_counts]),
                  len(xy_counts[xy_counts < max_counts])
                          / len(xy_counts) * 100))
plt.ylabel("# of xy pairs")
plt.xlabel("# of records")
plt.grid(linestyle=':')

# %% [markdown]
# ## Aggregate records by `pin`

# %% [markdown]
# ### Add column `total_sales_pin`
# Total records for each pin, generated as a separate DataFrame `df_pin` which represents Teranet records grouped and indexed by `pin`.
#
# `total_sales_pin` is added as a new column for Teranet records via a merge operation on `pin`.

# %%
# create a new DataFrame with daily aggregates per customer
col_rename = {'registration_date': 'total_sales_pin'}

df_pin = \
    df.groupby(['pin'])['registration_date'].count()\
        .reset_index().rename(columns=col_rename)

# join a new column to the original DataFrame
df = pd.merge(df,
              df_pin,
              left_on=['pin'],
              right_on=['pin'],
              how='left')
print("New column 'total_sales_pin' added to the DataFrame!")
# Out:
# New column 'total_sales_pin' added to the DataFrame!

# %% [markdown]
# ### Add column `prev_sales_pin`
# A new column is added to Teranet records capturing, for each transaction, a rolling count of previous records from this `pin`.

# %%
mask1 = df['registration_date'] > '1960'
mask2 = df['registration_date'] < '1965'
df_s = df[mask1 & mask2].copy()
len(df_s)
# Out:
# 3859

# %%
df_s.groupby('pin')\
    ['registration_date']\
    .expanding().count()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-691a848c3571> in <module>
#       1 df_s.groupby('pin')\
# ----> 2     ['registration_date']\
#       3     .expanding().count()
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\base.py in outer(self, *args, **kwargs)
#      27                 x = self._shallow_copy(x, groupby=self._groupby)
#      28                 return getattr(x, name)(*args, **kwargs)
# ---> 29             return self._groupby.apply(f)
#      30         outer.__name__ = name
#      31         return outer
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\base.py in f(x)
#      26             def f(x):
#      27                 x = self._shallow_copy(x, groupby=self._groupby)
# ---> 28                 return getattr(x, name)(*args, **kwargs)
#      29             return self._groupby.apply(f)
#      30         outer.__name__ = name
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in count(self, **kwargs)
#    1968     @Appender(_shared_docs['count'])
#    1969     def count(self, **kwargs):
# -> 1970         return super(Expanding, self).count(**kwargs)
#    1971
#    1972     @Substitution(name='expanding')
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in count(self)
#     930     def count(self):
#     931
# --> 932         blocks, obj, index = self._create_blocks()
#     933         # Validate the index
#     934         self._get_index(index=index)
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in _create_blocks(self)
#     114                 obj = obj.reindex(columns=obj.columns.difference([self.on]),
#     115                                   copy=False)
# --> 116         blocks = obj._to_dict_of_blocks(copy=False).values()
#     117
#     118         return blocks, obj, index
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\generic.py in _to_dict_of_blocks(self, copy)
#    5577         """
#    5578         return {k: self._constructor(v).__finalize__(self)
# -> 5579                 for k, v, in self._data.to_dict(copy=copy).items()}
#    5580
#    5581     def astype(self, dtype, copy=True, errors='raise', **kwargs):
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\internals\managers.py in to_dict(self, copy)
#     822
#     823         return {dtype: self.combine(blocks, copy=copy)
# --> 824                 for dtype, blocks in bd.items()}
#     825
#     826     def xs(self, key, axis=1, copy=True, takeable=False):
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\internals\managers.py in <dictcomp>(.0)
#     822
#     823         return {dtype: self.combine(blocks, copy=copy)
# --> 824                 for dtype, blocks in bd.items()}
#     825
#     826     def xs(self, key, axis=1, copy=True, takeable=False):
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\internals\managers.py in combine(self, blocks, copy)
#     678
#     679         axes = list(self.axes)
# --> 680         axes[0] = self.items.take(indexer)
#     681
#     682         return self.__class__(new_blocks, axes, do_integrity_check=False)
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\indexes\base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     797                 msg = 'Unable to fill values because {0} cannot contain NA'
#     798                 raise ValueError(msg.format(self.__class__.__name__))
# --> 799             taken = self.values.take(indices)
#     800         return self._shallow_copy(taken)
#     801
#
# KeyboardInterrupt:

# %%
t = time.time()
# add column 'prev_visits' to DataFrame with daily data
df_s['prev_sales_pin'] = \
    df_s.groupby('pin')['registration_date']\
        .expanding().count()\
        .astype('int') - 1 # current sale is not counted
elapsed = time.time() - t
print("New column 'prev_sales_pin' added to the DataFrame!"
      "\ntook {0:.2f} seconds.".format(elapsed))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-bec0b99c274c> in <module>
#       2 # add column 'prev_visits' to DataFrame with daily data
#       3 df_s['prev_sales_pin'] = \
# ----> 4     df_s.groupby('pin')['registration_date']\
#       5         .expanding().count()\
#       6         .astype('int') - 1 # current sale is not counted
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\base.py in outer(self, *args, **kwargs)
#      27                 x = self._shallow_copy(x, groupby=self._groupby)
#      28                 return getattr(x, name)(*args, **kwargs)
# ---> 29             return self._groupby.apply(f)
#      30         outer.__name__ = name
#      31         return outer
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\groupby\base.py in f(x)
#      26             def f(x):
#      27                 x = self._shallow_copy(x, groupby=self._groupby)
# ---> 28                 return getattr(x, name)(*args, **kwargs)
#      29             return self._groupby.apply(f)
#      30         outer.__name__ = name
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in count(self, **kwargs)
#    1968     @Appender(_shared_docs['count'])
#    1969     def count(self, **kwargs):
# -> 1970         return super(Expanding, self).count(**kwargs)
#    1971
#    1972     @Substitution(name='expanding')
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in count(self)
#     942             result = self._constructor(result, window=window, min_periods=0,
#     943                                        center=self.center,
# --> 944                                        closed=self.closed).sum()
#     945             results.append(result)
#     946
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in sum(self, *args, **kwargs)
#    1980     def sum(self, *args, **kwargs):
#    1981         nv.validate_expanding_func('sum', args, kwargs)
# -> 1982         return super(Expanding, self).sum(*args, **kwargs)
#    1983
#    1984     @Substitution(name='expanding')
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in sum(self, *args, **kwargs)
#    1014     def sum(self, *args, **kwargs):
#    1015         nv.validate_window_func('sum', args, kwargs)
# -> 1016         return self._apply('roll_sum', 'sum', **kwargs)
#    1017
#    1018     _shared_docs['max'] = dedent("""
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in _apply(self, func, name, window, center, check_minp, **kwargs)
#     839         results = []
#     840         for b in blocks:
# --> 841             values = self._prep_values(b.values)
#     842
#     843             if values.size == 0:
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\window.py in _prep_values(self, values, kill_inf)
#     215
#     216         if kill_inf:
# --> 217             values = values.copy()
#     218             values[np.isinf(values)] = np.NaN
#     219
#
# KeyboardInterrupt:

# %%
t = time.time()
# add column 'prev_visits' to DataFrame with daily data
df['prev_sales_pin'] = \
    df.groupby('pin')['registration_date']\
        .expanding().count()\
        .astype('int') - 1 # current sale is not counted
elapsed = time.time() - t
print("New column 'prev_sales_pin' added to the DataFrame!"
      "\ntook {0:.2f} seconds.".format(elapsed))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3593                 try:
# -> 3594                     value = value.reindex(self.index)._values
#    3595                 except Exception as e:
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4368             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 4369                                             tolerance=tolerance, method=method)
#    4370
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\indexes\multi.py in reindex(self, target, method, level, limit, tolerance)
#    2235                 # hopefully?
# -> 2236                 target = MultiIndex.from_tuples(target)
#    2237
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\indexes\multi.py in from_tuples(cls, tuples, sortorder, names)
#     395
# --> 396             arrays = list(lib.tuples_to_object_array(tuples).T)
#     397         elif isinstance(tuples, list):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.tuples_to_object_array()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long long'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1b20941218ad> in <module>
#       4     df.groupby('pin')['registration_date']\
#       5         .expanding().count()\
# ----> 6         .astype('int') - 1 # current sale is not counted
#       7 elapsed = time.time() - t
#       8 print("New column 'prev_sales_pin' added to the DataFrame!"
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3605
#    3606         if isinstance(value, Series):
# -> 3607             value = reindexer(value)
#    3608
#    3609         elif isinstance(value, DataFrame):
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3600
#    3601                     # other
# -> 3602                     raise TypeError('incompatible index of inserted column '
#    3603                                     'with frame index')
#    3604             return value
#
# TypeError: incompatible index of inserted column with frame index

# %%
t = time.time()
# add column 'prev_visits' to DataFrame with daily data
df4['prev_sales_pin'] = \
    df3.groupby('pin')['registration_date']\
        .transform(lambda x: x.expanding().count())\
        .astype('int') - 1 # current sale is not counted
elapsed = time.time() - t
print("New column 'prev_sales_pin' added to the DataFrame!"
      "\ntook {0:.2f} seconds.".format(elapsed))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\dask\dataframe\groupby.py in __getattr__(self, key)
#    1227         try:
# -> 1228             return self[key]
#    1229         except KeyError as e:
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\dask\dataframe\groupby.py in __getitem__(self, key)
#    1218         # error is raised from pandas
# -> 1219         g._meta = g._meta[key]
#    1220         return g
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#
# KeyError: 'Column not found: compute'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-209d4f0679a0> in <module>
#       2 # add column 'prev_visits' to DataFrame with daily data
#       3 df4['prev_sales_pin'] = \
# ----> 4     df3.groupby('pin').compute()['registration_date']\
#       5         .transform(lambda x: x.expanding().count())\
#       6         .astype('int') - 1 # current sale is not counted
#
# C:\ProgramData\Anaconda3\envs\gds\lib\site-packages\dask\dataframe\groupby.py in __getattr__(self, key)
#    1228             return self[key]
#    1229         except KeyError as e:
# -> 1230             raise AttributeError(e)
#    1231
#    1232     @derived_from(pd.core.groupby.DataFrameGroupBy)
#
# AttributeError: 'Column not found: compute'
