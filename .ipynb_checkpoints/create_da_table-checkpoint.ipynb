# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Create-DA-table-with-Teranet-aggregates" data-toc-modified-id="Create-DA-table-with-Teranet-aggregates-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Create DA table with Teranet aggregates</a></span><ul class="toc-item"><li><span><a href="#Proposed-table-structure" data-toc-modified-id="Proposed-table-structure-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Proposed table structure</a></span></li></ul></li><li><span><a href="#DA-data:-profiles-of-income-by-DA-from-2016-Census" data-toc-modified-id="DA-data:-profiles-of-income-by-DA-from-2016-Census-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DA data: profiles of income by DA from 2016 Census</a></span><ul class="toc-item"><li><span><a href="#Variable-POP_TOT_INC:-population-by-DA-from-2016-Census" data-toc-modified-id="Variable-POP_TOT_INC:-population-by-DA-from-2016-Census-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Variable <code>POP_TOT_INC</code>: population by DA from 2016 Census</a></span></li><li><span><a href="#Variable-MEDIAN_AFT_INC:-median-after-tax-income-by-DA-from-2016-Census" data-toc-modified-id="Variable-MEDIAN_AFT_INC:-median-after-tax-income-by-DA-from-2016-Census-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Variable <code>MEDIAN_AFT_INC</code>: median after-tax income by DA from 2016 Census</a></span></li><li><span><a href="#Variable-AVG_AFT_INC:-average-after-tax-income-by-DA-from-2016-Census" data-toc-modified-id="Variable-AVG_AFT_INC:-average-after-tax-income-by-DA-from-2016-Census-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Variable <code>AVG_AFT_INC</code>: average after-tax income by DA from 2016 Census</a></span></li></ul></li><li><span><a href="#Teranet-data" data-toc-modified-id="Teranet-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Teranet data</a></span><ul class="toc-item"><li><span><a href="#Validating-consistency-of-DA-geometry-from-Census-and-da_id-in-Teranet-records" data-toc-modified-id="Validating-consistency-of-DA-geometry-from-Census-and-da_id-in-Teranet-records-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Validating consistency of DA <code>geometry</code> from Census and <code>da_id</code> in Teranet records</a></span></li></ul></li><li><span><a href="#Resample-Teranet-data-per-time-per-DA" data-toc-modified-id="Resample-Teranet-data-per-time-per-DA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Resample Teranet data per time per DA</a></span><ul class="toc-item"><li><span><a href="#Teranet-records-from-1990-2017,-1-year-intervals" data-toc-modified-id="Teranet-records-from-1990-2017,-1-year-intervals-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Teranet records from 1990-2017, 1 year intervals</a></span><ul class="toc-item"><li><span><a href="#Resample-records" data-toc-modified-id="Resample-records-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Resample records</a></span></li><li><span><a href="#Sanity-check:-relationship-between-DA-population-and-count-of-Teranet-records" data-toc-modified-id="Sanity-check:-relationship-between-DA-population-and-count-of-Teranet-records-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Sanity check: relationship between DA population and count of Teranet records</a></span></li><li><span><a href="#Sanity-check:-relationship-between-DA-mean-income-and-mean-price-of-Teranet-records" data-toc-modified-id="Sanity-check:-relationship-between-DA-mean-income-and-mean-price-of-Teranet-records-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Sanity check: relationship between DA mean income and mean price of Teranet records</a></span></li><li><span><a href="#Sanity-check:-relationship-between-median-price-in-1990-and-median-price-in-2017,-per-DA" data-toc-modified-id="Sanity-check:-relationship-between-median-price-in-1990-and-median-price-in-2017,-per-DA-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Sanity check: relationship between median price in 1990 and median price in 2017, per DA</a></span></li><li><span><a href="#Sanity-check:-relationship-between-mean-price-in-2017-and-median-price-in-2017,-per-DA" data-toc-modified-id="Sanity-check:-relationship-between-mean-price-in-2017-and-median-price-in-2017,-per-DA-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Sanity check: relationship between mean price in 2017 and median price in 2017, per DA</a></span></li><li><span><a href="#Save-and-verify-results" data-toc-modified-id="Save-and-verify-results-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Save and verify results</a></span></li><li><span><a href="#Teranet-price-and-record-count-time-series-at-DA-level" data-toc-modified-id="Teranet-price-and-record-count-time-series-at-DA-level-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Teranet price and record count time series at DA level</a></span></li></ul></li><li><span><a href="#Teranet-records-from-1990-2017,-1-year-intervals" data-toc-modified-id="Teranet-records-from-1990-2017,-1-year-intervals-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Teranet records from 1990-2017, 1 year intervals</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Create DA table with Teranet aggregates
# This notebook contains the workflow to create a table of **Dissimination Areas (DAs)** with columns containing aggregates generated from Teranet dataset of real estate sales records (annual sales count, mean, median price).
#
# Proposed structure of the table (each record is a DA):
#
# ### Proposed table structure
#
# | DA id | Teranet 2017 count | ... | Teranet 1990 count |
# $\quad$|Teranet 2017 median price| ... | Teranet 1990 median price |
# $\quad$|Teranet 2017 mean price  | ... | Teranet 1990 mean price   |

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
from shapely.geometry import Polygon
import contextily as ctx

# %%
# os.chdir('Documents/repos/geo/')
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.idea',
#  '.ipynb_checkpoints',
#  'arcgis.ipynb',
#  'choropleth-map-example.png',
#  'create_da_table.ipynb',
#  'data',
#  'geo_doodle.py',
#  'my_functions_geo.py',
#  'new_workflow.ipynb',
#  'parking_Toronto.ipynb',
#  'README.md',
#  'Teranet_GTHA_DA_investigating_pins.ipynb',
#  'Teranet_GTHA_DA_spatial_join.ipynb',
#  'Teranet_GTHA_DA_workflow.ipynb',
#  '__pycache__']

# %% [markdown]
# ## DA data: profiles of income by DA from 2016 Census

# %%
# da_geo_source = 'https://opendata.arcgis.com/datasets/9d262f8a576842fbb2afbc8c51a64178_1.geojson'
da_geo_source = 'data/Profile_of_Income_by_Dissemination_Area__Greater_Toronto_Area_2016_Census.geojson'
da_income_gdf = gpd.read_file(da_geo_source)
da_income_gdf = da_income_gdf.set_index('OBJECTID')
print("GeoDataFrame 'da_income_gdf' with profile of income by dissimination areas created!")
# Out:
# GeoDataFrame 'da_income_gdf' with profile of income by dissimination areas created!

# %%
da_income_gdf.head(1)
# Out:
#              DAUID   CSDUID CSDNAME  POP_TOT_INC  NUM_TOT_INC_PVT_HH  \
# OBJECTID
# 3001      35190147  3519046  Aurora       1845.0              1750.0
#
#           MEDIAN_TOT_INC  NUM_AFT_TAX_INC_PVT_HH  MEDIAN_AFT_INC  \
# OBJECTID
# 3001             43221.0                  1755.0         38187.0
#
#           NUM_MKT_INC_PVT_HH  MEDIAN_MKT_INC  ...  \
# OBJECTID                                      ...
# 3001                  1665.0         43669.0  ...
#
#           AVG_AFTER_TAX_INC_CPL_W_CHILD  TOT_INC_LONE_PARENT_25_SAMP  \
# OBJECTID
# 3001                           176934.0                         80.0
#
#           AVG_INC_LONE_PARENT  AVG_AFTER_TAX_LONE_PARENT  \
# OBJECTID
# 3001                 161886.0                   116922.0
#
#           TOT_INC_NOT_IN_ECF_25_SAMP  AVG_INC_NOT_IN_ECF  \
# OBJECTID
# 3001                            90.0             48426.0
#
#           AVG_AFTER_TAX_INC_NOT_IN_ECF   Shape__Area  Shape__Length  \
# OBJECTID
# ...

# %%
da_income_columns = ['DAUID', 'CSDNAME', 'POP_TOT_INC',
                     'MEDIAN_AFT_INC', 'AVG_AFT_INC', 
                     'Shape__Area', 'geometry']

# %%
da_gdf = da_income_gdf[da_income_columns]
da_gdf.head(1)
# Out:
#              DAUID CSDNAME  POP_TOT_INC  MEDIAN_AFT_INC  AVG_AFT_INC  \
# OBJECTID
# 3001      35190147  Aurora       1845.0         38187.0      53052.0
#
#            Shape__Area                                           geometry
# OBJECTID
# 3001      3.418148e+06  POLYGON ((-79.461503331619 43.9741383351884, -...

# %% [markdown]
# ### Variable `POP_TOT_INC`: population by DA from 2016 Census

# %%
da_gdf.groupby('CSDNAME')['POP_TOT_INC'].sum().sort_values().plot(kind='barh')
plt.suptitle('Total population by DA from 2016 Census (POP_TOT_INC)')
# Out:
# Text(0.5, 0.98, 'Total population by DA from 2016 Census (POP_TOT_INC)')

# %% [markdown]
# ### Variable `MEDIAN_AFT_INC`: median after-tax income by DA from 2016 Census

# %%
sns.distplot(da_gdf['MEDIAN_AFT_INC'].dropna(), rug=True)

# %% [markdown]
# ### Variable `AVG_AFT_INC`: average after-tax income by DA from 2016 Census

# %%
sns.distplot(da_gdf['AVG_AFT_INC'].dropna(), rug=True)

# %% [markdown]
# ## Teranet data
#
# With column `da_id` (renamed from `OBJECTID`)
# * produced via a spatial join of the points from the full cleaned Teranet dataset (`HHSaleHistory_cleaned_v0.9.csv`) with geometries of Dissimination Areas from York Region Municipal Government - Open Data (`bndDisseminationAreaGTHA2016` in DEM) accessed via ArcGIS Hub (same as GeoDataFrame of profiles of income by DA above). (https://hub.arcgis.com/datasets/9d262f8a576842fbb2afbc8c51a64178_1?selectedAttribute=TOT_HHTI_PVT)

# %%
# verify the path to Teranet dataset
teranet_path = 'data/HHSaleHistory_cleaned_v0.9_GTHA_DA.csv'
# read Teranet dataset with a column containing Dissimination Areas id
teranet_da_df = pd.read_csv(teranet_path)
# drop unnecessary columns
teranet_da_df.drop(['Unnamed: 0', 'index', 'index_right'], axis=1, inplace=True)
# covert 'registration_date' to datetime data format
teranet_da_df['registration_date'] = pd.to_datetime(teranet_da_df['registration_date'])
teranet_da_df = teranet_da_df.set_index('registration_date')
teranet_da_df = teranet_da_df.sort_index()
print("Teranet sales data with 'da_id' was loaded into DataFrame 'teranet_da_df'!")
print("{0:,} records total in the DataFrame.".format(len(teranet_da_df)))
# Out:
# Teranet sales data with 'da_id' was loaded into DataFrame 'teranet_da_df'!
# 6,062,853 records total in the DataFrame.

# %% [markdown]
# ### Validating consistency of DA `geometry` from Census and `da_id` in Teranet records

# %%
# combine values in columns 'x' and 'y' into a POINT geometry object
# Point() is a function imported from shapely.geometry
geometry = [Point(xy) for xy in zip(teranet_da_df['x'], teranet_da_df['y'])]

# generate a new GeoDataFrame by adding point geometry to data frame 'teranet_sales_data'
teranet_sales_gdf = gpd.GeoDataFrame(teranet_da_df, geometry=geometry)
print("Geometry generated from 'x' and 'y' pairs, GeoDataFrame created!")
# Out:
# Geometry generated from 'x' and 'y' pairs, GeoDataFrame created!

# %%
focus_id = da_income_gdf.index[0] # index of focus polygon
focus_rad = 0.05 # ratio to zoom the map on focus polygon
# Setup figure and axis
f, ax = plt.subplots(1, figsize=(6, 6))
# Plot base layer of polygons
da_income_gdf.plot(ax=ax, facecolor='black',
                       linewidth=0.1, alpha=1)
# Select focal polygon
focus = da_income_gdf.loc[[focus_id], 'geometry']
# Plot focal polygon
focus.plot(ax=ax, facecolor='red', linewidth=0, alpha=0.5)
# Subset and plot Teranet records from focus DA
mask = teranet_sales_gdf['da_id'] == focus_id
teranet_subset = teranet_sales_gdf[mask]
teranet_subset.plot(ax=ax)
# Title
f.suptitle("DA {0} and its {1:,} Teranet records"
           .format(focus_id, sum(mask)))
# Style and display on screen
ax.set_ylim(focus.centroid.y.iloc[0] - focus_rad, focus.centroid.y.iloc[0] + focus_rad)
ax.set_xlim(focus.centroid.x.iloc[0] - focus_rad, focus.centroid.x.iloc[0] + focus_rad)
plt.show()

# %% [markdown]
# ## Resample Teranet data per time per DA

# %% [markdown]
# ### Teranet records from 1990-2017, 1 year intervals

# %% [markdown]
# #### Resample records

# %%
# Create annual subsets of Teranet records
first_year = 1990
final_year = 2017
year_range = list(range(first_year, final_year + 1))
# min and max price to filter outliers
min_price = 1000
max_price = 5000000
# loop over each year in the range, generate Teranet aggregates
for year in year_range:
    # set subset interval
    start_date = str(year) + '-01-01'
    end_date = str(year) + '-12-31'
    # subset Teranet data
    teranet_subset = \
        teranet_da_df[start_date:end_date].dropna(subset=['consideration_amt'])
    # remove outliers, 1'000 < price < 5'000'000
    mask1 = teranet_subset['consideration_amt'] > min_price
    mask2 = teranet_subset['consideration_amt'] < max_price
    teranet_subset = teranet_subset[mask1 & mask2]
    # generate count, mean and median price per DA from Teranet subset
    da_groups = teranet_subset.groupby('da_id')
    record_count = da_groups['consideration_amt'].count()
    mean_price = da_groups['consideration_amt'].mean()
    median_price = da_groups['consideration_amt'].median()
    # plot distributions 
    sns.distplot(mean_price)
    plt.axvline(mean_price.mean(), color='deeppink', linestyle='--')
    plt.suptitle("{0:,} records in Teranet subset from {1} to {2}"
                 .format(len(teranet_subset), start_date, end_date)
                 + "\nmean price: {0:,.2f}$".format(mean_price.mean()))
    plt.show()
    sns.distplot(median_price)
    plt.axvline(median_price.mean(), color='deeppink', linestyle='--')
    plt.suptitle("median price: {0:,.2f}$".format(median_price.mean()))
    plt.show()
    # remove outliers by record count (for display only)
    record_count_no = record_count[record_count < 200]
    sns.distplot(record_count_no)
    plt.axvline(record_count.mean(), color='deeppink', linestyle='--')
    plt.suptitle("{0:,} total records, mean records per DA: {1:,.2f}"
                 .format(record_count.sum(), record_count.mean()))
    plt.show()
    # save Teranet aggregates to GeoDataFrame 'da_gdf'
    da_gdf = da_gdf.join(mean_price)
    da_gdf = \
        da_gdf.rename(columns={'consideration_amt':'t_avg_' 
                                                   + str(year)})
    da_gdf = da_gdf.join(median_price)
    da_gdf = \
        da_gdf.rename(columns={'consideration_amt':'t_med_' 
                                                   + str(year)})
    da_gdf = da_gdf.join(record_count)    
    da_gdf = \
        da_gdf.rename(columns={'consideration_amt':'t_cnt_' 
                                                   + str(year)})
print("Yearly (from {0} to {1}) record count, mean and median "
      .format(year_range[0], year_range[-1]) + 
      "price derived from Teranet data "
      "has been added to GeoDataFrame 'da_gdf'!")
# Out:
# Yearly (from 1990 to 2017) record count, mean and median price derived from Teranet data has been added to GeoDataFrame 'da_gdf'!

# %%
# reorder columns
old_cols = list(da_gdf.columns[:7])
new_cols_avg = ['t_avg_' + str(year) for year in list(range(first_year, final_year + 1))]
new_cols_med = ['t_med_' + str(year) for year in list(range(first_year, final_year + 1))]
new_cols_cnt = ['t_cnt_' + str(year) for year in list(range(first_year, final_year + 1))]
new_cols = new_cols_med + new_cols_avg + new_cols_cnt
cols = old_cols + new_cols
da_gdf_1yr = da_gdf[cols]
da_gdf_1yr.head(1)
# Out:
#              DAUID CSDNAME  POP_TOT_INC  MEDIAN_AFT_INC  AVG_AFT_INC  \
# OBJECTID
# 3001      35190147  Aurora       1845.0         38187.0      53052.0
#
#            Shape__Area                                           geometry  \
# OBJECTID
# 3001      3.418148e+06  POLYGON ((-79.461503331619 43.9741383351884, -...
#
#           t_med_1990  t_med_1991  t_med_1992  ...  t_cnt_2008  t_cnt_2009  \
# OBJECTID                                      ...
# 3001        269990.0    240990.0    269574.5  ...        35.0        59.0
#
#           t_cnt_2010  t_cnt_2011  t_cnt_2012  t_cnt_2013  t_cnt_2014  \
# OBJECTID
# 3001            79.0        48.0        34.0        38.0        36.0
#
#           t_cnt_2015  t_cnt_2016  t_cnt_2017
# OBJECTID
# 3001            37.0        52.0        35.0
#
# [1 rows x 91 columns]

# %% [markdown]
# #### Sanity check: relationship between DA population and count of Teranet records

# %%
sns.jointplot(data=da_gdf, kind='reg',
              x='POP_TOT_INC', y='t_cnt_2015')

# %% [markdown]
# #### Sanity check: relationship between DA mean income and mean price of Teranet records

# %%
sns.jointplot(data=da_gdf, kind='reg',
              x='AVG_AFT_INC', y='t_avg_2016')

# %% [markdown]
# #### Sanity check: relationship between median price in 1990 and median price in 2017, per DA

# %%
sns.jointplot(data=da_gdf, kind='reg',
              x='t_med_2017', y='t_med_1990')

# %% [markdown]
# #### Sanity check: relationship between mean price in 2017 and median price in 2017, per DA

# %%
sns.jointplot(data=da_gdf, kind='reg',
              x='t_med_2017', y='t_avg_2017')

# %% [markdown]
# #### Save and verify results

# %%
csv_save_file_path = 'data/da_teranet_1yr_1990_2017.csv'
# save GeoDataFrame to a .csv file without the 'geometry' and 'index_right' columns
da_gdf_1yr.drop('geometry', axis=1).reset_index().to_csv(csv_save_file_path)
print("GeoDataFrame 'da_gdf' recorded to file {0}!"
      .format(csv_save_file_path))
# Out:
# GeoDataFrame 'da_gdf' recorded to file data/da_teranet_1yr_1990_2017.csv!

# %%
geojson_save_file_path = 'data/da_teranet_1yr_1990_2017.geojson'
# save GeoDataFrame to a .csv file without the 'geometry' and 'index_right' columns
da_gdf_1yr.reset_index().to_file(geojson_save_file_path)
print("GeoDataFrame 'da_gdf' recorded to file {0}!"
      .format(geojson_save_file_path))
# Out:
# GeoDataFrame 'da_gdf' recorded to file data/da_teranet_1yr_1990_2017.geojson!

# %%
test = pd.read_csv(csv_save_file_path)
test = test.drop('Unnamed: 0', axis=1).set_index('OBJECTID').sort_index()
test.head(1)
# Out:
#              DAUID CSDNAME  POP_TOT_INC  MEDIAN_AFT_INC  AVG_AFT_INC  \
# OBJECTID
# 1         35180171  Oshawa        410.0         31360.0      31855.0
#
#             Shape__Area  t_med_1990  t_med_1991  t_med_1992  t_med_1993  ...  \
# OBJECTID                                                                 ...
# 1         167737.956787    131000.0    125000.0    117750.0    107500.0  ...
#
#           t_cnt_2008  t_cnt_2009  t_cnt_2010  t_cnt_2011  t_cnt_2012  \
# OBJECTID
# 1               11.0         9.0         6.0        19.0        10.0
#
#           t_cnt_2013  t_cnt_2014  t_cnt_2015  t_cnt_2016  t_cnt_2017
# OBJECTID
# 1               23.0         6.0        18.0        24.0        17.0
#
# [1 rows x 90 columns]

# %%
test.columns
# Out:
# Index(['DAUID', 'CSDNAME', 'POP_TOT_INC', 'MEDIAN_AFT_INC', 'AVG_AFT_INC',
#        'Shape__Area', 't_med_1990', 't_med_1991', 't_med_1992', 't_med_1993',
#        't_med_1994', 't_med_1995', 't_med_1996', 't_med_1997', 't_med_1998',
#        't_med_1999', 't_med_2000', 't_med_2001', 't_med_2002', 't_med_2003',
#        't_med_2004', 't_med_2005', 't_med_2006', 't_med_2007', 't_med_2008',
#        't_med_2009', 't_med_2010', 't_med_2011', 't_med_2012', 't_med_2013',
#        't_med_2014', 't_med_2015', 't_med_2016', 't_med_2017', 't_avg_1990',
#        't_avg_1991', 't_avg_1992', 't_avg_1993', 't_avg_1994', 't_avg_1995',
#        't_avg_1996', 't_avg_1997', 't_avg_1998', 't_avg_1999', 't_avg_2000',
#        't_avg_2001', 't_avg_2002', 't_avg_2003', 't_avg_2004', 't_avg_2005',
#        't_avg_2006', 't_avg_2007', 't_avg_2008', 't_avg_2009', 't_avg_2010',
#        't_avg_2011', 't_avg_2012', 't_avg_2013', 't_avg_2014', 't_avg_2015',
# ...

# %% [markdown]
# #### Teranet price and record count time series at DA level

# %%
focus_id = 3
f, ax = plt.subplots(1)
ax2 = ax.twinx()
test.loc[focus_id, 't_med_1990':'t_med_2017'].plot(ax=ax, color='blue', 
                                                   label='Median')
test.loc[focus_id, 't_avg_1990':'t_avg_2017'].plot(ax=ax, color='red', 
                                                   label='Mean')
test.loc[focus_id, 't_cnt_1990':'t_cnt_2017'].plot(ax=ax2, color='darkgreen', 
                                                   label='Count')
ax.legend(loc='best')
ax2.legend(loc='best')
ax.set_title("Mean, median price and record count\nfrom Teranet data for DA {0}"
             .format(focus_id))
ax.set_xticklabels(list(range(1990, 2018, 5)))
plt.show()

# %%
test = gpd.read_file(geojson_save_file_path)
test = test.set_index('OBJECTID').sort_index()
test.head(1)
# Out:
#              DAUID CSDNAME  POP_TOT_IN  MEDIAN_AFT  AVG_AFT_IN     Shape__Are  \
# OBJECTID
# 1         35180171  Oshawa       410.0     31360.0     31855.0  167737.956787
#
#           t_med_1990  t_med_1991  t_med_1992  t_med_1993  ...  t_cnt_2009  \
# OBJECTID                                                  ...
# 1           131000.0    125000.0    117750.0    107500.0  ...         9.0
#
#           t_cnt_2010  t_cnt_2011  t_cnt_2012  t_cnt_2013  t_cnt_2014  \
# OBJECTID
# 1                6.0        19.0        10.0        23.0         6.0
#
#           t_cnt_2015  t_cnt_2016  t_cnt_2017  \
# OBJECTID
# 1               18.0        24.0        17.0
#
#                                                    geometry
# OBJECTID
# 1         POLYGON ((-78.86262753067101 43.884693385047, ...
#
# [1 rows x 91 columns]

# %%
year = 2005
var = 'avg'
col_name = 't_' + var + '_' + str(year)
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot base layer of polygons
test.plot(ax=ax, facecolor='black',
          linewidth=0.1, alpha=1)
test.dropna(subset=[col_name]).plot(column=col_name, 
                   scheme='fisher_jenks', ax=ax, legend=True)
# test.dropna(subset=[col_name]).to_crs(epsg=3857).plot(column=col_name, 
#                    scheme='fisher_jenks', ax=ax)
# ctx.add_basemap(ax, url=ctx.sources.ST_TONER_BACKGROUND, alpha=0.25)
# left_lim = -8850000
# bottom_lim = 5400000
# map_span = 25000
left_lim = -79.5
bottom_lim = 43.6
map_span = 0.2
ax.set_xlim(left_lim, left_lim + map_span)
ax.set_ylim(bottom_lim, bottom_lim + map_span)
plt.show()

# %%
year = 2017
var = 'avg'
col_name = 't_' + var + '_' + str(year)
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot base layer of polygons
test.plot(ax=ax, facecolor='black',
          linewidth=0.1, alpha=1)
test.dropna(subset=[col_name]).plot(column=col_name, 
                   scheme='fisher_jenks', ax=ax, legend=True)
# test.dropna(subset=[col_name]).to_crs(epsg=3857).plot(column=col_name, 
#                    scheme='fisher_jenks', ax=ax)
# ctx.add_basemap(ax, url=ctx.sources.ST_TONER_BACKGROUND, alpha=0.25)
# left_lim = -8850000
# bottom_lim = 5400000
# map_span = 25000
left_lim = -79.5
bottom_lim = 43.6
map_span = 0.2
ax.set_xlim(left_lim, left_lim + map_span)
ax.set_ylim(bottom_lim, bottom_lim + map_span)
plt.show()

# %%
year = 2005
var = 'cnt'
col_name = 't_' + var + '_' + str(year)
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot base layer of polygons
test.plot(ax=ax, facecolor='black',
          linewidth=0.1, alpha=1)
test.dropna(subset=[col_name]).plot(column=col_name, 
                   scheme='fisher_jenks', ax=ax, legend=True)
# test.dropna(subset=[col_name]).to_crs(epsg=3857).plot(column=col_name, 
#                    scheme='fisher_jenks', ax=ax)
# ctx.add_basemap(ax, url=ctx.sources.ST_TONER_BACKGROUND, alpha=0.25)
# left_lim = -8850000
# bottom_lim = 5400000
# map_span = 25000
left_lim = -79.5
bottom_lim = 43.6
map_span = 0.2
ax.set_xlim(left_lim, left_lim + map_span)
ax.set_ylim(bottom_lim, bottom_lim + map_span)
plt.show()

# %%
year = 2017
var = 'cnt'
col_name = 't_' + var + '_' + str(year)
f, ax = plt.subplots(1, figsize=(9, 9))
# Plot base layer of polygons
test.plot(ax=ax, facecolor='black',
          linewidth=0.1, alpha=1)
test.dropna(subset=[col_name]).plot(column=col_name, 
                   scheme='fisher_jenks', ax=ax, legend=True)
# test.dropna(subset=[col_name]).to_crs(epsg=3857).plot(column=col_name, 
#                    scheme='fisher_jenks', ax=ax)
# ctx.add_basemap(ax, url=ctx.sources.ST_TONER_BACKGROUND, alpha=0.25)
# left_lim = -8850000
# bottom_lim = 5400000
# map_span = 25000
left_lim = -79.5
bottom_lim = 43.6
map_span = 0.2
ax.set_xlim(left_lim, left_lim + map_span)
ax.set_ylim(bottom_lim, bottom_lim + map_span)
plt.show()

# %% [markdown]
# ### Teranet records from 1990-2017, 1 year intervals
